# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option('display.max_columns', None)

# %%
# Look the dtypes of numerical and categorical columns and make changes where appropriate - Already done in the other notebook

# %%
numerical = pd.read_csv('numerical7_02.csv', index_col=None)
numerical
# Out:
#        ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  MALEMILI  \
# 0         8901      0  3712  60.000000     5.0      6.0    0         0
# 1         9401      1  5202  46.000000     6.0      9.0   16         0
# 2         9001      1     0  61.611649     3.0      1.0    2         0
# 3         8701      0  2801  70.000000     1.0      4.0    2         0
# 4         8601      0  2001  78.000000     3.0      2.0   60         1
# ...        ...    ...   ...        ...     ...      ...  ...       ...
# 95407     9601      1     0  61.611649     5.0      6.0    0        14
# 95408     9601      1  5001  48.000000     7.0      9.0    1         0
# 95409     9501      1  3801  60.000000     5.0      6.0    0         0
# 95410     8601      0  4005  58.000000     7.0      6.0    0         0
# 95411     8801      2  1801  80.000000     5.0      8.0    3         1
#
#        MALEVET  VIETVETS  WWIIVETS  LOCALGOV  STATEGOV  FEDGOV  WEALTH2  \
# ...

# %%
# def cont_or_disc(dataframe, threshold):
#     continuous_df = pd.DataFrame()
#     discrete_df = pd.DataFrame()
    
#     for column in dataframe.columns:
#         unique_values = dataframe[column].nunique()
#         if unique_values > threshold:
#             continuous_df[column] = dataframe[column]
#         else:
#             discrete_df[column] = dataframe[column]
    
#     return continuous_df, discrete_df

# continuous_df, discrete_df = cont_or_disc(numerical, 200)

# %%
# continuous_df

# %%
# discrete_df

# %%
categorical = pd.read_csv('categorical7_02.csv', index_col=None)
categorical
# Out:
#        STATE  CLUSTER HOMEOWNR GENDER  DATASRCE RFA_2R RFA_2A GEOCODE2  \
# 0         IL       36        U      F         0      L      E        C
# 1         CA       14        H      M         3      L      G        A
# 2         NC       43        U      M         3      L      E        C
# 3         CA       44        U      F         3      L      E        C
# 4         FL       16        H      F         3      L      F        A
# ...      ...      ...      ...    ...       ...    ...    ...      ...
# 95407  other       27        U      M         0      L      G        C
# 95408     TX       24        H      M         3      L      F        A
# 95409     MI       30        U      M         0      L      E        B
# 95410     CA       24        H      F         2      L      F        A
# 95411     NC       24        U      F         3      L      G        C
#
#       DOMAIN_A
# 0            T
# 1            S
# 2            R
# 3            R
# 4            S
# ...        ...
# ...

# %%
categorical = categorical.astype('object')

# %%
y = pd.read_csv('target7_02.csv', index_col=None)
y
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
y = y.drop(['TARGET_D'], axis=1) # Dropping the TARGET
y
# Out:
#        TARGET_B
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 95407         0
# 95408         0
# 95409         0
# 95410         1
# 95411         0
#
# [95412 rows x 1 columns]

# %%
y.reset_index(drop=True, inplace=True)

# %%
y = y.astype(int)

# %%
X = pd.concat([numerical, categorical], axis=1)
X
# Out:
#        ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  MALEMILI  \
# 0         8901      0  3712  60.000000     5.0      6.0    0         0
# 1         9401      1  5202  46.000000     6.0      9.0   16         0
# 2         9001      1     0  61.611649     3.0      1.0    2         0
# 3         8701      0  2801  70.000000     1.0      4.0    2         0
# 4         8601      0  2001  78.000000     3.0      2.0   60         1
# ...        ...    ...   ...        ...     ...      ...  ...       ...
# 95407     9601      1     0  61.611649     5.0      6.0    0        14
# 95408     9601      1  5001  48.000000     7.0      9.0    1         0
# 95409     9501      1  3801  60.000000     5.0      6.0    0         0
# 95410     8601      0  4005  58.000000     7.0      6.0    0         0
# 95411     8801      2  1801  80.000000     5.0      8.0    3         1
#
#        MALEVET  VIETVETS  WWIIVETS  LOCALGOV  STATEGOV  FEDGOV  WEALTH2  \
# ...

# %%
# Split the data into a training set and a test set.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
# Split further into train_num and train_cat. Also test_num and test_cat
X_train_num = X_train.select_dtypes(include = np.number)
X_train_cat = X_train.select_dtypes(include = object)
X_test_num = X_test.select_dtypes(include = np.number)
X_test_cat = X_test.select_dtypes(include = object)

# %%
# Scale the features either by using MinMax Scaler or a Standard Scaler. (train_num, test_num)
from sklearn.preprocessing import MinMaxScaler

# Scaling data
# tranforming training data
transformer = MinMaxScaler().fit(X_train_num) # need to keep transformer
X_train_normalized = transformer.transform(X_train_num)
X_train_norm = pd.DataFrame(X_train_normalized, columns=X_train_num.columns)
X_train_norm

# tranforming testing data: we use the transformer that was trained on the training data
X_test_normalized = transformer.transform(X_test_num)
X_test_norm = pd.DataFrame(X_test_normalized)
X_test_norm.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.784946  0.000026  0.000000  0.624862  0.666667  0.666667  0.000000
# 1  0.569892  0.000718  0.000000  0.624862  0.666667  0.666667  0.000000
# 2  0.641577  0.000000  0.648919  0.350515  0.500000  0.222222  0.000000
# 3  0.354839  0.000000  0.000000  0.624862  0.000000  0.444444  0.000000
# 4  0.856631  0.000000  0.309063  0.690722  0.500000  0.666667  0.016598
#
#         7         8         9         10        11        12        13   \
# 0  0.020202  0.191919  0.363636  0.161616  0.131313  0.010101  0.080460
# 1  0.000000  0.313131  0.454545  0.555556  0.050505  0.000000  0.000000
# 2  0.000000  0.010101  0.000000  0.000000  0.131313  0.020202  0.022989
# 3  0.000000  0.313131  0.303030  0.292929  0.111111  0.030303  0.034483
# 4  0.000000  0.262626  0.171717  0.616162  0.090909  0.040404  0.045977
#
#         14        15        16        17   18        19        20        21   \
# ...

# %%
# Encode the categorical features using One-Hot Encoding or Ordinal Encoding. (train_cat, test_cat)
# fit only on train data, transform both train and test
# again re-concatenate train_num and train_cat as X_train as well as test_num and test_cat as X_test

X_train_cat = pd.get_dummies(X_train_cat, 
                             columns=['STATE', 'CLUSTER', 'HOMEOWNR','GENDER', 'DATASRCE',  'RFA_2R', 'RFA_2A', 'GEOCODE2', 'DOMAIN_A'],
                             drop_first=True)
X_train_cat

# X TEST CAT
X_test_cat  = pd.get_dummies(X_test_cat, 
                            columns=['STATE', 'CLUSTER', 'HOMEOWNR','GENDER', 'DATASRCE',  'RFA_2R', 'RFA_2A', 'GEOCODE2', 'DOMAIN_A'],
                            drop_first=True)
# Out:
# C:\Users\laiag\AppData\Local\Temp\ipykernel_9256\2659182196.py:5: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_train_cat = pd.get_dummies(X_train_cat,
# C:\Users\laiag\AppData\Local\Temp\ipykernel_9256\2659182196.py:11: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_test_cat  = pd.get_dummies(X_test_cat,

# %%
# verify that dummies columns are in the same order and that the same column was dropped
list(zip(list(X_train_cat.columns),list(X_test_cat.columns)))
list(X_train_cat.columns)==list(X_test_cat.columns)
# Out:
# True

# %%
# Resetting indexes 
X_train_norm.reset_index(drop=True, inplace=True)  # Add inplace=True
X_test_norm.reset_index(drop=True, inplace=True)

X_train_cat.reset_index(drop=True, inplace=True)
X_test_cat.reset_index(drop=True, inplace=True)

# %%
# build X_train and X_test
X_train_processed = np.concatenate([X_train_norm, X_train_cat], axis=1)
X_test_processed = np.concatenate([X_test_norm, X_test_cat], axis=1)

# %%
X_train_processed
# Out:
# array([[7.13261649e-01, 0.00000000e+00, 6.48918641e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [8.56630824e-01, 7.17911902e-04, 5.35633368e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.69892473e-01, 7.17911902e-04, 4.53244078e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        ...,
#        [7.84946237e-01, 0.00000000e+00, 0.00000000e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.11469534e-01, 5.12794216e-05, 3.19361483e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [4.98207885e-01, 2.56909902e-02, 3.19361483e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
y_train
# Out:
#        TARGET_B
# 88309         0
# 49426         0
# 74450         0
# 67492         0
# 24531         0
# ...         ...
# 87513         0
# 85159         0
# 9448          0
# 57533         0
# 3223          0
#
# [76329 rows x 1 columns]

# %%
y_test
# Out:
#        TARGET_B
# 72627         0
# 16269         0
# 19026         0
# 11620         0
# 73959         0
# ...         ...
# 89463         0
# 64849         0
# 51142         0
# 41673         0
# 63744         0
#
# [19083 rows x 1 columns]

# %%
# Fit a logistic regression model on the training data
from sklearn.linear_model import LogisticRegression

classification_model = LogisticRegression()
classification_model.fit(X_train_processed, y_train)
# Out:
# C:\Users\laiag\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\laiag\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Check the accuracy on the test data
predictions = classification_model.predict(X_test_processed)
predictions
classification_model.score(X_test_processed, y_test)
# Out:
# 0.9468112980139392

# %%
# Managing imbalance in the dataset

# %%
trainset = pd.concat([X_train, y_train], axis=1)

# %%
trainset['TARGET_B'].value_counts()
# Out:
# 0    72501
# 1     3828
# Name: TARGET_B, dtype: int64

# %%
from sklearn.utils import resample

category_0 = trainset[trainset['TARGET_B'] == 0]
category_1 = trainset[trainset['TARGET_B'] == 1]

# %%
#Downsampling (undersampling)

# %%
# category_0_undersampled = resample(category_0, 
#                                    replace=False, 
#                                    n_samples = len(category_1))

# %%
# print(category_0_undersampled.shape)
# print(category_1.shape)

# %%
# data_downsampled = pd.concat([category_0_undersampled, category_1], axis=0)

# %%
# data_downsampled['TARGET_B'].value_counts()

# %%
# y_train_imp = data_downsampled['TARGET_B']
# X_train_imp = data_downsampled.drop('TARGET_B', axis=1)

# %%
# I've problems with this method: 
# I don't know If I can use the processed train data - It doesn't work for me
# If I do it with the not processed data, should I repeat all the steps to process it before modeling?
# I've tried this way but I have some errors, then I used the SMOTE, but I want to understand this method too

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=100, k_neighbors=3)
X_train_SMOTE, y_train_SMOTE = sm.fit_resample(X_train_processed,y_train)

X_train_SMOTE.shape
# Out:
# (145002, 399)

# %%
# Fit a logistic regression model on the training data balanced
from sklearn.linear_model import LogisticRegression

classification_model = LogisticRegression()
classification_model.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# C:\Users\laiag\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\laiag\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Check the accuracy on the test data
predictions_SMOTE = classification_model.predict(X_test_processed)
predictions
classification_model.score(X_test_processed, y_test)
# Out:
# 0.6055651627102657
